# %% [markdown]
# # プログラム修了認定アプリ
# * 以下を実行するとブラウザに, Googleでのサインインを求めるページが現れるので, g.ecc アカウントでサインインしてください
# * その後アプリケーション wings-credit-count が許可を求めてくるので許可してください

# %%
import pandas as pd
import program_completion_check as pcc
pd.set_option("display.max_rows", None)

try:
    GC
except:
    GC = pcc.get_client()
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=1071794110392-ph1p7v4polr2a4k3jgg6art4cgfv5ig9.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A53183%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fspreadsheets.readonly&state=KKLWI8peQFilwrx1Msxcs0ylUKdFba&access_type=offline

# %% [markdown]
# (1) 当該プログラムに登録している学生のリスト
# * プログラム担当者が作る (おそらく始めからどこかに存在している)
# * 必須フィールド
#   * 学籍番号 : 形式は UTAS の学籍番号の形式に合わせる (48196459 みたいな)
# * URL は Google Drive の Google Spreadsheet の URL
#   * 注: **アップロードした Excel そのままでは現状開けない (修正したい・その予定)**
#   * 開けるようにするには Excel をGoogle Drive上で開き, File -> Google Spreadsheetとして保存する
# * SHEET は 番号 (0から始まる何枚目かを表す番号) もしくはシートの名前
# * 以下をSHIFT + ENTERで実行するとシートの読み込みと必須フィールドのチェックが行われる
#
# 以下同様

# %%
PROGRAM_STUDENTS_URL = "https://docs.google.com/spreadsheets/d/1fxk_V9YZMvLAWk9N-g3NU5ygMfWZ4WcveZ3yH9jh-PU/"
PROGRAM_STUDENTS_SHEET = 0

PROGRAM_STUDENTS = pcc.validate_program_students(GC, PROGRAM_STUDENTS_URL, sheet=PROGRAM_STUDENTS_SHEET)
print(f"{PROGRAM_STUDENTS.size} 行あります (先頭5行は以下です)")
PROGRAM_STUDENTS.head(5)
# Out:
# 156 行あります (先頭5行は以下です)
#        学籍番号        学生氏名
# 0  97917764   はりすた いるんぬ
# 1  97522092    まーらー るぴょ
# 2  97007146  おおいずみ ひろしぇ
# 3  95337881   むばっぺ きゅりん
# 4  92480580    べんぜま りんる

# %% [markdown]
# (2) UTAS から抽出した成績表 (本部学務課から送られてくる想定)
#
# 必須フィールド:
# * 共通ＩＤ
# * 学籍番号
# * 学生氏名
# * 学生氏名カナ
# * 学生所属
# * 年度
# * 時間割所属
# * 時間割コード
# * 開講科目名
# * 科目コード
# * 科目名
# * 主担当教員名
# * 主担当教員共通ID
# * 開講区分名
# * 合否区分
# * 単位数

# %%
UTAS_GRADE_URL = "https://docs.google.com/spreadsheets/d/1HploSNLzKuvhJcIev6WCzwGzjZOikvADFLzzmP2kSJU/"
UTAS_GRADE_SHEET = 0

UTAS_GRADE = pcc.validate_utas_grade(GC, UTAS_GRADE_URL, sheet=UTAS_GRADE_SHEET)
print(f"{UTAS_GRADE.size} 行あります (先頭5行は以下です)")
UTAS_GRADE.head(5)
# Out:
# 24150 行あります (先頭5行は以下です)
#        学籍番号     学生氏名   学生氏名カナ          学生所属    年度        時間割所属     時間割コード  \
# 0  90009839  らべるん みゃ  ラベルン ミャ  前も同じことやった研究科  2024   なんくるないさ研究科     115932
# 1  90009839  らべるん みゃ  ラベルン ミャ  前も同じことやった研究科  2023  けっきょく元通り研究科  8428-8815
# 2  90009839  らべるん みゃ  ラベルン ミャ  前も同じことやった研究科  2024  とくに目的はない研究科     631049
# 3  90009839  らべるん みゃ  ラベルン ミャ  前も同じことやった研究科  2023   名称未定（仮）研究科     946324
# 4  90009839  らべるん みゃ  ラベルン ミャ  前も同じことやった研究科  2021  だれが責任取るの研究科  9227-8556
#
#          開講科目名      科目コード          科目名        主担当教員名   主担当教員共通ID 開講区分名 合否区分  \
# 0  よろしくお願いします学     115932  よろしくお願いします学  みなもとの よしつねりん  7178031896    A1   合格
# 1  ゆるふわプログラミング  8428-8815  ゆるふわプログラミング       ごるばちょふん  1980066864    S2   合格
# 2    気づいたら夜明け学     631049    気づいたら夜明け学      まるこ ぽろろん  3324889321  A1A2  履修中
# 3   時間が溶ける情報科学     946324   時間が溶ける情報科学        はんにばるん  1254417563  S1S2   合格
# 4     気合と根性の数理  9227-8556     気合と根性の数理    しーざー じゅりあな  4256520100    S2  不合格
#
#    単位数
# 0  1.0
# 1  2.0
# 2  1.0
# 3  2.0
# 4  1.0

# %% [markdown]
# (3) 科目表 = 当該プログラムの科目表
#
# 必須フィールド:
# * 科目コード (形式は UTAS の科目コードと合わせる)
# * 開始年度
# * 終了年度

# %%
PROGRAM_COURSES_URL = "https://docs.google.com/spreadsheets/d/1zIJGOZ6Lfxki4YoaDGG_UcBYhlmSxs2QVK5h0VmMpNw/"
PROGRAM_COURSES_SHEET = 0

PROGRAM_COURSES = pcc.validate_program_subjects(GC, PROGRAM_COURSES_URL, sheet=PROGRAM_COURSES_SHEET)
PROGRAM_COURSES = pcc.validate_program_subjects(GC, PROGRAM_COURSES_URL, sheet=PROGRAM_COURSES_SHEET)
print(f"{PROGRAM_COURSES.size} 行あります (先頭5行は以下です)")
PROGRAM_COURSES.head(5)
# Out:
# 60 行あります (先頭5行は以下です)
#        科目コード  開始年度  終了年度
# 0  8428-8815  2022  2022
# 1     442352  2020  9999
# 2  7554-1915  2022  2025
# 3  9227-8556  2025  2025
# 4  0336-2612  2020  2021

# %% [markdown]
# # 実際の修了認定チェック!

# %%
CREDIT, RESULT_XLSX = pcc.do_check(PROGRAM_STUDENTS, UTAS_GRADE, PROGRAM_COURSES)
print(f"{CREDIT.size} 行あります. 結果を {RESULT_XLSX} に保存しました")
CREDIT
# Out:
# 73 行あります. 結果を 認定単位.xlsx に保存しました
#                                   認定単位
# 学籍番号     学生氏名        学生氏名カナ
# 90009839 らべるん みゃ     ラベルン ミャ       2.5
# 90032585 いにえす たりん    イニエス タリン      1.0
# 90043626 ぜんで いやりん    ゼンデ イヤリン      4.0
# 90259100 はにゅう ゆづりゅ   ハニュウ ユヅリュ     2.5
# 90603142 でぃかぷり おれおん  ディカプリ オレオン    3.0
# 90678261 えりっく さてぃん   エリック サティン     0.0
# 91170366 がりれお るんた    ガリレオ ルンタ      1.0
# 91428426 あいしゅ たいんるん  アイシュ タインルン    0.0
# 91648834 ふろーれ んすぴ    フローレ ンスピ      0.0
# 91813571 なだる らふぁみゅ   ナダル ラファミュ     3.5
# 91831401 じぇいく ぎれりん   ジェイク ギレリン     0.0
# 91969589 めしりお ねるん    メシリオ ネルン      4.5
# 92480580 べんぜま りんる    ベンゼマ リンル      4.0
# 92687964 けいと うぃんり    ケイト ウィンリ      4.0
# 92824178 きむたくん たくやん  キムタクン タクヤン    5.0
# 93204970 よしざわ りょうち   ヨシザワ リョウチ     0.0
# 93334068 まーく らふりん    マーク ラフリン      4.0
# 93388235 さかもとは やとりん  サカモトハ ヤトリン    0.0
# 93764586 めりる すとりゃ    メリル ストリャ      0.5
# 93935869 ほんだけ いすけちゃ  ホンダケ イスケチャ    0.0
# 94163088 ばっはん るんみ    バッハン ルンミ      5.0
# 94239790 たかなし さらら    タカナシ サララ      6.0
# 94358751 くろーす りんぬ    クロース リンヌ      2.0
# 94377242 じぇな おてりん    ジェナ オテリン      3.0
# 94542720 わーぐな るんちゃ   ワーグナ ルンチャ     1.0
# 94655496 あでるる ぴょみ    アデルル ピョミ      0.0
# 94685874 まーご っとりん    マーゴ ットリン      0.0
# 94869247 すあれす りんぴょ   スアレス リンピョ     6.5
# 94927953 じょだま いけるん   ジョダマ イケルン     1.0
# 95065382 じゃすてぃ んびりゅ  ジャスティ ンビリュ    0.5
# 95217373 べん あふりん     ベン アフリン       1.0
# 95337881 むばっぺ きゅりん   ムバッペ キュリン     0.5
# 95342262 じょーじ くるりん   ジョージ クルリン     2.0
# 95435169 とむるん くるーちゃ  トムルン クルーチャ    1.0
# 95487087 きゅりまり りんぬ   キュリマリ リンヌ     1.0
# 95609915 らいあん ごすりん   ライアン ゴスリン     2.5
# 95621033 ていすう ふとちゃ   テイスウ フトチャ     3.0
# 95648568 じぇし かちゃり    ジェシ カチャリ      4.5
# 95731503 べねでぃ くとりん   ベネディ クトリン     6.0
# 95859571 にしじま ひでとん   ニシジマ ヒデトン     3.0
# 95924674 もどりち るかりん   モドリチ ルカリン     5.5
# 96038981 えみりー ぶらりん   エミリー ブラリン     4.5
# 96113096 ながとも ゆうぴょ   ナガトモ ユウピョ     1.5
# 96265941 だるびしゅ ゆうにゃ  ダルビシュ ユウニャ    3.5
# 96478099 めしりお ぴょりん   メシリオ ピョリン     2.5
# 96653405 とむ ほらりん     トム ホラリン       5.0
# 96708611 かりすて ふりん    カリステ フリン      1.0
# 96948164 そんふん みんりん   ソンフン ミンリン     4.0
# 97007146 おおいずみ ひろしぇ  オオイズミ ヒロシェ    0.5
# 97518013 じぇにふぁ ろれみゅ  ジェニファ ロレミュ    2.0
# 97522092 まーらー るぴょ    マーラー ルピョ      7.5
# 97818030 みとま りんぴょ    ミトマ リンピョ      1.0
# 97917764 はりすた いるんぬ   ハリスタ イルンヌ     2.0
# 98206979 ぼるうさ いんたん   ボルウサ インタン     4.0
# 98466497 べーとー べんちゃ   ベートー ベンチャ     0.0
# 98633742 えんどう りんみゅ   エンドウ リンミュ     2.0
# 98692177 はりー すたぴょ    ハリー スタピョ      0.0
# 98859883 いけえ りかこぴ    イケエ リカコピ      6.0
# 98865289 すだまちゃ まさきゅ  スダマチャ マサキュ    7.0
# 98935855 むらかみ むねきゅん  ムラカミ ムネキュン    0.0
# 98979186 ふくだん みらきゅ   フクダン ミラキュ     3.5
# 98995825 でんぜる わしりん   デンゼル ワシリン     0.0
# 98997051 さかぐてぃ けんたろぴ サカグティ ケンタロピ   0.0
# 99281446 ふぇでら ろじゃりん  フェデラ ロジャリン    0.0
# 99317829 よしだ りんちゃ    ヨシダ リンチャ      2.0
# 99327728 えまま そんりん    エママ ソンリン      2.0
# 99366306 うぃる すみりん    ウィル スミリン      0.5
# 99434229 あんじぇり なりゅ   アンジェリ ナリュ     0.0
# 99442524 まね りんぬ      マネ リンヌ        5.0
# 99526434 もーつぁ るとぴ    モーツァ ルトピ      6.0
# 99608533 やまだて つとん    ヤマダテ ツトン      3.0
# 99790509 かわぐてぃ はるにゃ  カワグティ ハルニャ    3.0
# 99982824 えでぃ れどりん    エディ レドリン      3.5
